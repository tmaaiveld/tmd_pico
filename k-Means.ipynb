# %%
from pathlib import Path
from sklearn.cluster import KMeans
import pandas as pd
from joblib import load, dump
import time

# %load_ext jupyternotify

# %% [markdown]
# # Train $k$-Means

# %% [markdown]
# Dimensionality reduction technique to preprocess the PubMed embeddings.
#   - 1-3 clusterings over PubMed columns (depending on if categories are valuable)
#     - k means clustering grid search should be made more extensive at some point
#     - params can be chosen based on resulting tree models' feature importance values
#     - explore sample weighting for this
#
# KCV is currently not implemented, so $k$-Means sees the validation set data. This may not be a huge problem, considering it is unsupervised and does not see the labels, so for now I'll only leave out the test set here (not the validation set).
#
# - produce k folds of indices in train-test-split.ipynb and save to file
# - use these indices to split off the validation set each loop
#
# `for fold, indices in enumerate(k_folds)`:
# - train the model on X, generate predictions on y
# - save predictions to folder
#
# `when done:`
# concatenate the data to produce a full set of labelings which kNN has not seen values of during training
#
# another option: learn the best $k$-Means parameters ($k$) by doing supervised learning. Then replace PM columns entirely with either the learned label or the clustering.

# %%
data = pd.read_parquet('data/split/train.parquet')
cols = data.columns[data.columns.str.startswith('PM')]
models_path = Path('models/knn') # evaluation structure
models_path.mkdir(exist_ok=True, parents=True)

# %%
clust_grid = [4] # [4,6,8,10]
max_iter = 100 # set to 100
n_init = 10

# %%
for clust_count in clust_grid:
#     subdir = Path(f'n{clust_count}') # kcv
    start_time = time.time()
    
    embeddings = data.loc(axis=1)[cols]
    clust_name = f'{clust_count}_{n_init}x{max_iter}'

    km = KMeans(n_clusters=clust_count, n_init=n_init, max_iter=max_iter, random_state=1, verbose=1)

    km.fit(embeddings)
    clustering = km.predict(embeddings)
    
    clust_df = pd.DataFrame(clustering, index=data.index, columns=[f'knn_{clust_count}'])
    clust_df.to_parquet(f'data\\features\\PubMed_{clust_name}.parquet')
    
    dump(km, models_path / f'km_n{clust_count}.joblib') 
    
    print(time.time() - start_time)
    
    # %notify -m f"Completed testing for {clust_count}. Time remaining to test all k: {rem_time}"
    
# %notify -m f"finished training kNN for k= {', '.join([str(c) for c in clust_grid])}"
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 19460256.546391312
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 18799444.139010645
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 18381468.22819186
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 18291739.985818926
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 18272311.481779687
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 18261454.21530041
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 18229028.696881436
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 18199741.232194297
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 18184032.736645877
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 18178195.96734036
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 18173329.15307683
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 18172528.373808138
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 18172375.01105098
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 18172339.06569472
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 18172330.16372624
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 18172325.518997524
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 18172320.78714838
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 18172319.972961064
# center shift 4.284898e-06 within tolerance 8.270496e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 19552158.61902492
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 18998290.93278803
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 18677348.719991412
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 18514401.62604815
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 18456589.146341406
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 18436032.118159443
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 18426052.881723803
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 18422004.50508886
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 18418964.758997183
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 18415899.792326953
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 18413000.509049866
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 18411284.172708873
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 18409510.464635987
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 18406649.454522423
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 18398258.01293085
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 18390587.204448607
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 18381556.977053314
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 18369944.32692987
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 18349395.442179706
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 18330608.25789552
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 18296044.803289693
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 18282209.03840343
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 18275970.63744632
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 18243955.63828915
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 18233563.775586538
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 18219808.357444946
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 18182226.080550633
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 18179993.111807525
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 18179822.926136952
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 18179806.773705535
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 18179774.033027194
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 18179767.6470616
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 18179766.26590422
# center shift 5.590955e-06 within tolerance 8.270496e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 18917003.815462798
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 18814538.853512894
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 18714603.93344889
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 18610834.827577107
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 18516355.219647363
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 18377436.12642116
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 18296900.596517757
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 18263874.986876536
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 18252222.76121897
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 18247386.57290611
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 18246387.87022469
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 18244087.785780054
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 18243763.905303784
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 18243642.18527903
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 18243620.934689343
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 18243554.12618588
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 18243536.72288365
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 18243531.788463037
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 18243524.218140133
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 18243523.67519714
# center shift 7.880934e-06 within tolerance 8.270496e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 19615376.71983821
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 19390888.803105637
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 19214461.902680233
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 19066152.63221886
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 18918296.45242985
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 18801113.073164202
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 18688761.231669817
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 18647980.44665966
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 18618226.035249814
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 18589579.484223254
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 