# %%
import time
import warnings
from pathlib import Path
import numpy as np
import pandas as pd

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    import xgboost as xgb
    
pd.options.display.float_format = '{:20,.5f}'.format

PIO = {"participants", "interventions", "outcomes"}

# %%
def hotcode(df):

    cat_cols = set(df.select_dtypes(include=['category']).columns)
    print(f"Generating one-hot coding for columns {', '.join(list(cat_cols))}")

    dummies = pd.get_dummies(df[cat_cols].copy(), columns=cat_cols, dtype=bool)

    df = downcast(pd.concat([df.drop(cat_cols, axis=1), dummies], axis=1))
    print('hotcode complete.')
          
#     dropcols = df.loc[:,(df.sum() == 0)].columns
                   
#     df = df.drop(dropcols, axis=1)

    return df


def downcast(df):
    unsigned = df.select_dtypes(include=['uint8', 'uint16', 'int8', 'int16', 'int32', 'int64']).columns
    for col in unsigned:
        df[col] = df[col].apply(pd.to_numeric, downcast='signed')

    return df
          
          
def print_attrs(obj, only_attrs=False, only_names=False):
    
    attrs = [s for s in dir(obj) if not s[:2] == '__']
    
    for attr in attrs:
        if not callable(getattr(obj, attr)):
            print(f'\n*** ATTR: xgtrain.{attr} ***')
            if not only_names: print(getattr(obj, attr))

        elif not only_attrs:
            print(f'\n*** METHOD: xgtrain.{attr} ***')
            try:
                if not only_names: print(getattr(obj, attr)())
            except:
                print('failed')
          
def write_lines(path, collection):
    with (path).open('w') as f:
        namestr = '\n'.join(list(collection))
        f.write(namestr)

# %% [markdown]
# # Load data
#
# Data preparation; clear the memory after running.

# %%
selected_label = 'interventions'
df = pd.read_parquet('data/split/train3_100.parquet')

labels = df.copy()[PIO]
features = hotcode(
    df.copy().drop(PIO, axis=1)
)

num_pos = labels[selected_label].sum()
num_neg = len(labels[selected_label]) - num_pos
weight = num_neg / num_pos

weights = ((labels[selected_label] * weight) + 1); weights = weights/max(weights)

# features.insert(0, selected_label, df[selected_label])
# features.insert(1, 'class_weight', weights)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-e96d7ba16456> in <module>
#       1 selected_label = 'interventions'
# ----> 2 df = pd.read_parquet('data/split/train3_100.parquet')
#       3
#       4 labels = df.copy()[PIO]
#       5 features = hotcode(
#
# NameError: name 'pd' is not defined

# %%
# dmatrix = xgb.DMatrix(features.reset_index(drop=True), label=labels[selected_label], weight=weights)

# %%
dir_name = Path(f'data\\xgb_test\\{selected_label}')
dir_name.mkdir(exist_ok=True,parents=True)

write_lines(dir_name / 'feature_names.txt', dmatrix.feature_names)
write_lines(dir_name / 'feature_types.txt', dmatrix.feature_types)
# write_lines(dir_name / 'handle.txt', dmatrix.handle)

# %% [markdown]
# # Model script

# %%
print(list(globals().keys())[25:])
# Out:
# ['time', 'warnings', 'Path', 'dump_svmlight_file', 'train_test_split', 'xgb', 'PIO', '_i3', 'hotcode', 'downcast', 'print_attrs', 'write_lines', '_i4', 'selected_label', 'df', 'labels', 'features', 'num_pos', 'num_neg', 'weight', 'weights', '_i5', 'dmatrix', '_i6', 'dir_name', '_i7', '_7', '_i8', '_i9', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_17', '_i18', '_18', '_i19']

# %%
xg_train = dmatrix
del warnings, dump_svmlight_file, hotcode, downcast, df, labels, features, weight, weights, dmatrix

# %%
dmatrix.feature_names
# Out:
# ['stopword',
#  'punctuation',
#  'is_upper',
#  'is_lower',
#  'cap_first',
#  'is_int',
#  'is_dec',
#  'first_sent',
#  'last_sent',
#  'first_word',
#  'last_word',
#  'FIRST_WORD_LAG1',
#  'FIRST_WORD_LAG2',
#  'LAST_WORD_LAG-2',
#  'LAST_WORD_LAG-1',
#  'doc_loc',
#  'sent_id',
#  'sent_loc',
#  'dist_to_parent',
#  'PMFT_1',
#  'PMFT_2',
#  'PMFT_3',
#  'PMFT_4',
#  'PMFT_5',
#  'PMFT_6',
#  'PMFT_7',
#  'PMFT_8',
#  'PMFT_9',
#  'PMFT_10',
#  'PMFT_11',
#  'PMFT_12',
#  'PMFT_13',
#  'PMFT_14',
#  'PMFT_15',
#  'PMFT_16',
#  'PMFT_17',
#  'PMFT_18',
#  'PMFT_19',
#  'PMFT_20',
#  'PMFT_21',
#  'PMFT_22',
#  'PMFT_23',
#  'PMFT_24',
#  'PMFT_25',
#  'PMFT_26',
#  'PMFT_27',
#  'PMFT_28',
#  'PMFT_29',
#  'PMFT_30',
#  'PMFT_31',
#  'PMFT_32',
#  'PMFT_33',
#  'PMFT_34',
#  'PMFT_35',
#  'PMFT_36',
#  'PMFT_37',
#  'PMFT_38',
#  'PMFT_39',
#  'PMFT_40',
#  'PMFT_41',
#  'PMFT_42',
#  'PMFT_43',
#  'PMFT_44',
#  'PMFT_45',
#  'PMFT_46',
#  'PMFT_47',
#  'PMFT_48',
#  'PMFT_49',
#  'PMFT_50',
#  'PMFT_51',
#  'PMFT_52',
#  'PMFT_53',
#  'PMFT_54',
#  'PMFT_55',
#  'PMFT_56',
#  'PMFT_57',
#  'PMFT_58',
#  'PMFT_59',
#  'PMFT_60',
#  'PMFT_61',
#  'PMFT_62',
#  'PMFT_63',
#  'PMFT_64',
#  'PMFT_65',
#  'PMFT_66',
#  'PMFT_67',
#  'PMFT_68',
#  'PMFT_69',
#  'PMFT_70',
#  'PMFT_71',
#  'PMFT_72',
#  'PMFT_73',
#  'PMFT_74',
#  'PMFT_75',
#  'PMFT_76',
#  'PMFT_77',
#  'PMFT_78',
#  'PMFT_79',
#  'PMFT_80',
#  'PMFT_81',
#  'PMFT_82',
#  'PMFT_83',
#  'PMFT_84',
#  'PMFT_85',
#  'PMFT_86',
#  'PMFT_87',
#  'PMFT_88',
#  'PMFT_89',
#  'PMFT_90',
#  'PMFT_91',
#  'PMFT_92',
#  'PMFT_93',
#  'PMFT_94',
#  'PMFT_95',
#  'PMFT_96',
#  'PMFT_97',
#  'PMFT_98',
#  'PMFT_99',
#  'PMFT_100',
#  'PMFT_101',
#  'PMFT_102',
#  'PMFT_103',
#  'PMFT_104',
#  'PMFT_105',
#  'PMFT_106',
#  'PMFT_107',
#  'PMFT_108',
#  'PMFT_109',
#  'PMFT_110',
#  'PMFT_111',
#  'PMFT_112',
#  'PMFT_113',
#  'PMFT_114',
#  'PMFT_115',
#  'PMFT_116',
#  'PMFT_117',
#  'PMFT_118',
#  'PMFT_119',
#  'PMFT_120',
#  'PMFT_121',
#  'PMFT_122',
#  'PMFT_123',
#  'PMFT_124',
#  'PMFT_125',
#  'PMFT_126',
#  'PMFT_127',
#  'PMFT_128',
#  'PMFT_129',
#  'PMFT_130',
#  'PMFT_131',
#  'PMFT_132',
#  'PMFT_133',
#  'PMFT_134',
#  'PMFT_135',
#  'PMFT_136',
#  'PMFT_137',
#  'PMFT_138',
#  'PMFT_139',
#  'PMFT_140',
#  'PMFT_141',
#  'PMFT_142',
#  'PMFT_143',
#  'PMFT_144',
#  'PMFT_145',
#  'PMFT_146',
#  'PMFT_147',
#  'PMFT_148',
#  'PMFT_149',
#  'PMFT_150',
#  'PMFT_151',
#  'PMFT_152',
#  'PMFT_153',
#  'PMFT_154',
#  'PMFT_155',
#  'PMFT_156',
#  'PMFT_157',
#  'PMFT_158',
#  'PMFT_159',
#  'PMFT_160',
#  'PMFT_161',
#  'PMFT_162',
#  'PMFT_163',
#  'PMFT_164',
#  'PMFT_165',
#  'PMFT_166',
#  'PMFT_167',
#  'PMFT_168',
#  'PMFT_169',
#  'PMFT_170',
#  'PMFT_171',
#  'PMFT_172',
#  'PMFT_173',
#  'PMFT_174',
#  'PMFT_175',
#  'PMFT_176',
#  'PMFT_177',
#  'PMFT_178',
#  'PMFT_179',
#  'PMFT_180',
#  'PMFT_181',
#  'PMFT_182',
#  'PMFT_183',
#  'PMFT_184',
#  'PMFT_185',
#  'PMFT_186',
#  'PMFT_187',
#  'PMFT_188',
#  'PMFT_189',
#  'PMFT_190',
#  'PMFT_191',
#  'PMFT_192',
#  'PMFT_193',
#  'PMFT_194',
#  'PMFT_195',
#  'PMFT_196',
#  'PMFT_197',
#  'PMFT_198',
#  'PMFT_199',
#  'PMFT_200',
#  'tfidf',
#  'TFIDF_LAG-2',
#  'TFIDF_LAG-1',
#  'TFIDF_LAG1',
#  'TFIDF_LAG2',
#  'par_xpos_$',
#  'par_xpos_,',
#  'par_xpos_-RRB-',
#  'par_xpos_.',
#  'par_xpos_ADD',
#  'par_xpos_AFX',
#  'par_xpos_CC',
#  'par_xpos_CD',
#  'par_xpos_DT',
#  'par_xpos_FW',
#  'par_xpos_GW',
#  'par_xpos_IN',
#  'par_xpos_JJ',
#  'par_xpos_JJR',
#  'par_xpos_JJS',
#  'par_xpos_LS',
#  'par_xpos_MD',
#  'par_xpos_NN',
#  'par_xpos_NNP',
#  'par_xpos_NNPS',
#  'par_xpos_NNS',
#  'par_xpos_PDT',
#  'par_xpos_POS',
#  'par_xpos_PRP',
#  'par_xpos_PRP$',
#  'par_xpos_RB',
#  'par_xpos_RBR',
#  'par_xpos_RBS',
#  'par_xpos_RP',
#  'par_xpos_SYM',
#  'par_xpos_TO',
#  'par_xpos_UH',
#  'par_xpos_VB',
#  'par_xpos_VBD',
#  'par_xpos_VBG',
#  'par_xpos_VBN',
#  'par_xpos_VBP',
#  'par_xpos_VBZ',
#  'par_xpos_WDT',
#  'par_xpos_WP',
#  'par_xpos_WP$',
#  'par_xpos_WRB',
#  'par_xpos__',
#  'UPOS_LAG2_ADJ',
#  'UPOS_LAG2_ADP',
#  'UPOS_LAG2_ADV',
#  'UPOS_LAG2_AUX',
#  'UPOS_LAG2_CCONJ',
#  'UPOS_LAG2_DET',
#  'UPOS_LAG2_INTJ',
#  'UPOS_LAG2_NOUN',
#  'UPOS_LAG2_NUM',
#  'UPOS_LAG2_PART',
#  'UPOS_LAG2_PRON',
#  'UPOS_LAG2_PROPN',
#  'UPOS_LAG2_PUNCT',
#  'UPOS_LAG2_SCONJ',
#  'UPOS_LAG2_SYM',
#  'UPOS_LAG2_VERB',
#  'UPOS_LAG2_X',
#  'UPOS_LAG2__',
#  'par_lemma_00',
#  'par_lemma_000',
#  'par_lemma_01',
#  'par_lemma_03',
#  'par_lemma_04',
#  'par_lemma_05',
#  'par_lemma_07',
#  'par_lemma_10',
#  'par_lemma_100',
#  'par_lemma_11',
#  'par_lemma_12',
#  'par_lemma_120',
#  'par_lemma_13',
#  'par_lemma_14',
#  'par_lemma_15',
#  'par_lemma_150',
#  'par_lemma_16',
#  'par_lemma_17',
#  'par_lemma_18',
#  'par_lemma_19',
#  'par_lemma_20',
#  'par_lemma_200',
#  'par_lemma_21',
#  'par_lemma_22',
#  'par_lemma_23',
#  'par_lemma_24',
#  'par_lemma_25',
#  'par_lemma_250',
#  'par_lemma_26',
#  'par_lemma_27',
#  'par_lemma_28',
#  'par_lemma_29',
#  'par_lemma_30',
#  'par_lemma_300',
#  'par_lemma_31',
#  'par_lemma_32',
#  'par_lemma_33',
#  'par_lemma_34',
#  'par_lemma_35',
#  'par_lemma_36',
#  'par_lemma_37',
#  'par_lemma_38',
#  'par_lemma_39',
#  'par_lemma_40',
#  'par_lemma_400',
#  'par_lemma_41',
#  'par_lemma_42',
#  'par_lemma_43',
#  'par_lemma_44',
#  'par_lemma_45',
#  'par_lemma_46',
#  'par_lemma_47',
#  'par_lemma_48',
#  'par_lemma_49',
#  'par_lemma_50',
#  'par_lemma_500',
#  'par_lemma_51',
#  'par_lemma_52',
#  'par_lemma_53',
#  'par_lemma_54',
#  'par_lemma_55',
#  'par_lemma_56',
#  'par_lemma_57',
#  'par_lemma_58',
#  'par_lemma_59',
#  'par_lemma_60',
#  'par_lemma_61',
#  'par_lemma_62',
#  'par_lemma_63',
#  'par_lemma_64',
#  'par_lemma_65',
#  'par_lemma_66',
#  'par_lemma_67',
#  'par_lemma_68',
#  'par_lemma_69',
#  'par_lemma_70',
#  'par_lemma_71',
#  'par_lemma_72',
#  'par_lemma_73',
#  'par_lemma_74',
#  'par_lemma_75',
#  'par_lemma_76',
#  'par_lemma_77',
#  'par_lemma_78',
#  'par_lemma_79',
#  'par_lemma_80',
#  'par_lemma_81',
#  'par_lemma_82',
#  'par_lemma_83',
#  'par_lemma_84',
#  'par_lemma_85',
#  'par_lemma_86',
#  'par_lemma_87',
#  'par_lemma_88',
#  'par_lemma_89',
#  'par_lemma_90',
#  'par_lemma_91',
#  'par_lemma_92',
#  'par_lemma_93',
#  'par_lemma_94',
#  'par_lemma_95',
#  'par_lemma_96',
#  'par_lemma_97',
#  'par_lemma_98',
#  'par_lemma_99',
#  'par_lemma__',
#  'par_lemma_abdominal',
#  'par_lemma_ability',
#  'par_lemma_absence',
#  'par_lemma_absolute',
#  'par_lemma_accuracy',
#  'par_lemma_acetate',
#  'par_lemma_achieve',
#  'par_lemma_acid',
#  'par_lemma_activation',
#  'par_lemma_active',
#  'par_lemma_activity',
#  'par_lemma_acupuncture',
#  'par_lemma_acute',
#  'par_lemma_addition',
#  'par_lemma_additional',
#  'par_lemma_adherence',
#  'par_lemma_adjuvant',
#  'par_lemma_administer',
#  'par_lemma_administration',
#  'par_lemma_adolescent',
#  'par_lemma_adult',
#  'par_lemma_advanced',
#  'par_lemma_adverse',
#  'par_lemma_affect',
#  'par_lemma_age',
#  'par_lemma_aged',
#  'par_lemma_agent',
#  'par_lemma_agonist',
#  'par_lemma_aim',
#  'par_lemma_airway',
#  'par_lemma_alcohol',
#  'par_lemma_allergic',
#  'par_lemma_allocate',
#  'par_lemma_alpha',
#  'par_lemma_alternative',
#  'par_lemma_ambulatory',
#  'par_lemma_anaesthesia',
#  'par_lemma_analgesia',
#  'par_lemma_analgesic',
#  'par_lemma_analog',
#  'par_lemma_analysis',
#  'par_lemma_anesthesia',
#  'par_lemma_anesthetic',
#  'par_lemma_angina',
#  'par_lemma_angiotensin',
#  'par_lemma_antagonist',
#  'par_lemma_anterior',
#  'par_lemma_antibiotic',
#  'par_lemma_antibody',
#  'par_lemma_antihypertensive',
#  'par_lemma_anxiety',
#  'par_lemma_aortic',
#  'par_lemma_appear',
#  'par_lemma_application',
#  'par_lemma_apply',
#  'par_lemma_appropriate',
#  'par_lemma_area',
#  'par_lemma_arm',
#  'par_lemma_arterial',
#  'par_lemma_artery',
#  'par_lemma_aspirin',
#  'par_lemma_assess',
#  'par_lemma_assessment',
#  'par_lemma_assign',
#  'par_lemma_assist',
#  'par_lemma_associate',
#  'par_lemma_association',
#  'par_lemma_asthma',
#  'par_lemma_atrial',
#  'par_lemma_attention',
#  'par_lemma_author',
#  'par_lemma_autism',
#  'par_lemma_autistic',
#  'par_lemma_available',
#  'par_lemma_average',
#  'par_lemma_balance',
#  'par_lemma_basal',
#  'par_lemma_base',
#  'par_lemma_baseline',
#  'par_lemma_basis',
#  'par_lemma_behavior',
#  'par_lemma_behavioral',
#  'par_lemma_beneficial',
#  'par_lemma_benefit',
#  'par_lemma_best',
#  'par_lemma_beta',
#  'par_lemma_better',
#  'par_lemma_biopsy',
#  'par_lemma_birth',
#  'par_lemma_bladder',
#  'par_lemma_bleed',
#  'par_lemma_blind',
#  'par_lemma_blinded',
#  'par_lemma_block',
#  'par_lemma_blood',
#  'par_lemma_body',
#  'par_lemma_bone',
#  'par_lemma_bowel',
#  'par_lemma_brain',
#  'par_lemma_breast',
#  'par_lemma_brief',
#  'par_lemma_bupivacaine',
#  'par_lemma_bypass',
#  'par_lemma_calcium',
#  'par_lemma_calculate',
#  'par_lemma_cancer',
#  'par_lemma_capacity',
#  'par_lemma_carcinoma',
#  'par_lemma_cardiac',
#  'par_lemma_cardiovascular',
#  'par_lemma_care',
#  'par_lemma_case',
#  'par_lemma_catheter',
#  'par_lemma_cause',
#  'par_lemma_cell',
#  'par_lemma_center',
#  'par_lemma_central',
#  'par_lemma_cerebral',
#  'par_lemma_cervical',
#  'par_lemma_cessation',
#  'par_lemma_challenge',
#  'par_lemma_change',
#  'par_lemma_characteristic',
#  'par_lemma_checklist',
#  'par_lemma_chemotherapy',
#  'par_lemma_child',
#  'par_lemma_childhood',
#  'par_lemma_choice',
#  'par_lemma_cholesterol',
#  'par_lemma_chronic',
#  'par_lemma_cisplatin',
#  'par_lemma_class',
#  'par_lemma_clearance',
#  'par_lemma_clinical',
#  'par_lemma_clinically',
#  'par_lemma_clonidine',
#  'par_lemma_cm',
#  'par_lemma_cognitive',
#  'par_lemma_cohort',
#  'par_lemma_collect',
#  'par_lemma_colorectal',
#  'par_lemma_combination',
#  'par_lemma_combine',
#  'par_lemma_common',
#  'par_lemma_communication',
#  'par_lemma_community',
#  'par_lemma_comparable',
#  'par_lemma_comparative',
#  'par_lemma_compare',
#  'par_lemma_comparison',
#  'par_lemma_complete',
#  'par_lemma_completion',
#  'par_lemma_compliance',
#  'par_lemma_complication',
#  'par_lemma_component',
#  'par_lemma_composite',
#  'par_lemma_computer',
#  'par_lemma_concentration',
#  'par_lemma_concurrent',
#  'par_lemma_condition',
#  'par_lemma_conduct',
#  'par_lemma_confidence',
#  'par_lemma_confirm',
#  'par_lemma_consecutive',
#  'par_lemma_consistent',
#  'par_lemma_consumption',
#  'par_lemma_contact',
#  'par_lemma_contain',
#  'par_lemma_content',
#  'par_lemma_continuous',
#  'par_lemma_contrast',
#  'par_lemma_control',
#  'par_lemma_controls',
#  'par_lemma_conventional',
#  'par_lemma_core',
#  'par_lemma_coronary',
#  'par_lemma_correlate',
#  'par_lemma_cortisol',
#  'par_lemma_cost',
#  'par_lemma_counseling',
#  'par_lemma_count',
#  'par_lemma_course',
#  'par_lemma_cream',
#  'par_lemma_creatinine',
#  'par_lemma_criterion',
#  'par_lemma_crossover',
#  'par_lemma_cure',
#  'par_lemma_current',
#  'par_lemma_curve',
#  'par_lemma_cycle',
#  'par_lemma_cyclophosphamide',
#  'par_lemma_daily',
#  'par_lemma_data',
#  'par_lemma_day',
#  'par_lemma_death',
#  'par_lemma_decrease',
#  'par_lemma_degree',
#  'par_lemma_deliver',
#  'par_lemma_delivery',
#  'par_lemma_demographic',
#  'par_lemma_density',
#  'par_lemma_dental',
#  'par_lemma_dependent',
#  'par_lemma_depression',
#  'par_lemma_depressive',
#  'par_lemma_design',
#  'par_lemma_detect',
#  'par_lemma_detection',
#  'par_lemma_determine',
#  'par_lemma_develop',
#  'par_lemma_development',
#  'par_lemma_developmental',
#  'par_lemma_diabete',
#  'par_lemma_diabetic',
#  'par_lemma_diagnose',
#  'par_lemma_diagnosis',
#  'par_lemma_diagnostic',
#  'par_lemma_diastolic',
#  'par_lemma_diclofenac',
#  'par_lemma_die',
#  'par_lemma_diet',
#  'par_lemma_dietary',
#  'par_lemma_difference',
#  'par_lemma_different',
#  'par_lemma_diltiazem',
#  'par_lemma_direct',
#  'par_lemma_disability',
#  'par_lemma_discharge',
#  'par_lemma_discuss',
#  'par_lemma_disease',
#  'par_lemma_disorder',
#  'par_lemma_distress',
#  'par_lemma_divide',
#  'par_lemma_do',
#  'par_lemma_document',
#  'par_lemma_dosage',
#  'par_lemma_dose',
#  'par_lemma_doxorubicin',
#  'par_lemma_drug',
#  'par_lemma_duration',
#  'par_lemma_dysfunction',
#  'par_lemma_earlier',
#  'par_lemma_early',
#  'par_lemma_education',
#  'par_lemma_educational',
#  'par_lemma_effect',
#  'par_lemma_effective',
#  'par_lemma_effectiveness',
#  'par_lemma_efficacy',
#  'par_lemma_ejection',
#  'par_lemma_elderly',
#  'par_lemma_elective',
#  'par_lemma_elevate',
#  'par_lemma_eligible',
#  'par_lemma_emotional',
#  'par_lemma_enalapril',
#  'par_lemma_end',
#  'par_lemma_endoscopic',
#  'par_lemma_endothelial',
#  'par_lemma_endpoint',
#  'par_lemma_energy',
#  'par_lemma_enrol',
#  'par_lemma_enter',
#  'par_lemma_enzyme',
#  'par_lemma_epidural',
#  'par_lemma_episode',
#  'par_lemma_equal',
#  'par_lemma_equivalent',
#  'par_lemma_eradication',
#  'par_lemma_error',
#  'par_lemma_essential',
#  'par_lemma_establish',
#  'par_lemma_estrogen',
#  'par_lemma_evaluable',
#  'par_lemma_evaluate',
#  'par_lemma_evaluation',
#  'par_lemma_event',
#  'par_lemma_evidence',
#  'par_lemma_examine',
#  'par_lemma_excretion',
#  'par_lemma_exercise',
#  'par_lemma_expect',
#  'par_lemma_experience',
#  'par_lemma_experiment',
#  'par_lemma_experimental',
#  'par_lemma_exposure',
#  'par_lemma_expression',
#  'par_lemma_extend',
#  'par_lemma_extent',
#  'par_lemma_eye',
#  'par_lemma_facial',
#  'par_lemma_factor',
#  'par_lemma_fail',
#  'par_lemma_family',
#  'par_lemma_fasting',
#  'par_lemma_fat',
#  'par_lemma_fatigue',
#  'par_lemma_fatty',
#  'par_lemma_feasibility',
#  'par_lemma_feed',
#  'par_lemma_feedback',
#  'par_lemma_female',
#  'par_lemma_femoral',
#  'par_lemma_fentanyl',
#  'par_lemma_fever',
#  'par_lemma_fewer',
#  'par_lemma_fibrillation',
#  'par_lemma_final',
#  'par_lemma_finding',
#  'par_lemma_flow',
#  'par_lemma_fluid',
#  'par_lemma_fluorouracil',
#  'par_lemma_follow',
#  'par_lemma_formation',
#  'par_lemma_formulation',
#  'par_lemma_fraction',
#  'par_lemma_free',
#  'par_lemma_frequency',
#  'par_lemma_frequent',
#  'par_lemma_frequently',
#  'par_lemma_function',
#  'par_lemma_functional',
#  'par_lemma_future',
#  'par_lemma_gain',
#  'par_lemma_gastric',
#  'par_lemma_gastrointestinal',
#  'par_lemma_gel',
#  'par_lemma_gender',
#  'par_lemma_general',
#  'par_lemma_give',
#  'par_lemma_global',
#  'par_lemma_glucose',
#  'par_lemma_good',
#  'par_lemma_gov',
#  'par_lemma_graft',
#  'par_lemma_greater',
#  'par_lemma_group',
#  'par_lemma_growth',
#  'par_lemma_guide',
#  'par_lemma_half',
#  'par_lemma_hand',
#  'par_lemma_head',
#  'par_lemma_headache',
#  'par_lemma_heal',
#  'par_lemma_health',
#  'par_lemma_healthy',
#  'par_lemma_heart',
#  'par_lemma_hemodynamic',
#  'par_lemma_hemoglobin',
#  'par_lemma_heparin',
#  'par_lemma_hepatic',
#  'par_lemma_hepatitis',
#  'par_lemma_high',
#  'par_lemma_higher',
#  'par_lemma_highest',
#  'par_lemma_highly',
#  'par_lemma_hip',
#  'par_lemma_history',
#  'par_lemma_home',
#  'par_lemma_hormone',
#  'par_lemma_hospital',
#  'par_lemma_hospitalization',
#  'par_lemma_hour',
#  'par_lemma_hr',
#  'par_lemma_human',
#  'par_lemma_hypertension',
#  'par_lemma_hypertensive',
#  'par_lemma_hypotension',
#  'par_lemma_hypothesis',
#  'par_lemma_identify',
#  'par_lemma_iii',
#  'par_lemma_illness',
#  'par_lemma_immediate',
#  'par_lemma_immediately',
#  'par_lemma_immune',
#  'par_lemma_impact',
#  'par_lemma_impair',
#  'par_lemma_impairment',
#  'par_lemma_implant',
#  'par_lemma_implication',
#  'par_lemma_importance',
#  'par_lemma_important',
#  'par_lemma_improve',
#  'par_lemma_incidence',
#  'par_lemma_include',
#  'par_lemma_increase',
#  'par_lemma_index',
#  'par_lemma_indicate',
#  'par_lemma_individual',
#  'par_lemma_induce',
#  'par_lemma_induction',
#  'par_lemma_infant',
#  'par_lemma_infarction',
#  'par_lemma_infect',
#  'par_lemma_infection',
#  'par_lemma_inflammation',
#  'par_lemma_inflammatory',
#  'par_lemma_influence',
#  'par_lemma_information',
#  'par_lemma_infusion',
#  'par_lemma_inhal',
#  'par_lemma_inhibition',
#  'par_lemma_inhibitor',
#  'par_lemma_injection',
#  'par_lemma_insulin',
#  'par_lemma_intake',
#  'par_lemma_intensity',
#  'par_lemma_intensive',
#  'par_lemma_intention',
#  'par_lemma_interaction',
#  'par_lemma_interferon',
#  'par_lemma_interval',
#  'par_lemma_intervention',
#  'par_lemma_intraoperative',
#  'par_lemma_intravenous',
#  'par_lemma_intravenously',
#  'par_lemma_invasive',
#  'par_lemma_investigate',
#  'par_lemma_investigation',
#  'par_lemma_involved',
#  'par_lemma_iron',
#  'par_lemma_irritability',
#  'par_lemma_ischemic',
#  'par_lemma_isoflurane',
#  'par_lemma_joint',
#  'par_lemma_kg',
#  'par_lemma_kidney',
#  'par_lemma_knee',
#  'par_lemma_know',
#  'par_lemma_knowledge',
#  'par_lemma_laboratory',
#  'par_lemma_lack',
#  'par_lemma_language',
#  'par_lemma_laparoscopic',
#  'par_lemma_large',
#  'par_lemma_larger',
#  'par_lemma_laser',
#  'par_lemma_late',
#  'par_lemma_later',
#  'par_lemma_learn',
#  'par_lemma_leave',
#  'par_lemma_length',
#  'par_lemma_lesion',
#  'par_lemma_leukemia',
#  'par_lemma_level',
#  'par_lemma_lidocaine',
#  'par_lemma_life',
#  'par_lemma_likely',
#  'par_lemma_limitation',
#  'par_lemma_limited',
#  'par_lemma_line',
#  'par_lemma_linear',
#  'par_lemma_lipid',
#  'par_lemma_lipoprotein',
#  'par_lemma_little',
#  'par_lemma_liver',
#  'par_lemma_local',
#  'par_lemma_long',
#  'par_lemma_longer',
#  'par_lemma_loss',
#  'par_lemma_low',
#  'par_lemma_lower',
#  'par_lemma_lung',
#  'par_lemma_m2',
#  'par_lemma_main',
#  'par_lemma_maintenance',
#  'par_lemma_major',
#  'par_lemma_male',
#  'par_lemma_man',
#  'par_lemma_management',
#  'par_lemma_marker',
#  'par_lemma_marrow',
#  'par_lemma_mass',
#  'par_lemma_match',
#  'par_lemma_maternal',
#  'par_lemma_maximal',
#  'par_lemma_maximum',
#  'par_lemma_mean',
#  'par_lemma_measurement',
#  'par_lemma_mechanism',
#  'par_lemma_mediat',
#  'par_lemma_medical',
#  'par_lemma_medication',
#  'par_lemma_mental',
#  'par_lemma_metabolic',
#  'par_lemma_metabolism',
#  'par_lemma_metastase',
#  'par_lemma_metastatic',
#  'par_lemma_method',
#  'par_lemma_methotrexate',
#  'par_lemma_mg',
#  'par_lemma_microg',
#  'par_lemma_microgram',
#  'par_lemma_midazolam',
#  'par_lemma_migraine',
#  'par_lemma_mild',
#  'par_lemma_milk',
#  'par_lemma_min',
#  'par_lemma_minimal',
#  'par_lemma_minor',
#  'par_lemma_minute',
#  'par_lemma_mix',
#  'par_lemma_ml',
#  'par_lemma_mm',
#  'par_lemma_mmhg',
#  'par_lemma_mmol',
#  'par_lemma_model',
#  'par_lemma_moderate',
#  'par_lemma_modify',
#  'par_lemma_monitor',
#  'par_lemma_monotherapy',
#  'par_lemma_month',
#  'par_lemma_mood',
#  'par_lemma_morbidity',
#  'par_lemma_morphine',
#  'par_lemma_mortality',
#  'par_lemma_motor',
#  'par_lemma_multicenter',
#  'par_lemma_multicentre',
#  'par_lemma_multiple',
#  'par_lemma_muscle',
#  'par_lemma_myocardial',
#  'par_lemma_naltrexone',
#  'par_lemma_nasal',
#  'par_lemma_nausea',
#  'par_lemma_necessary',
#  'par_lemma_neck',
#  'par_lemma_need',
#  'par_lemma_needle',
#  'par_lemma_negative',
#  'par_lemma_nerve',
#  'par_lemma_new',
#  'par_lemma_ng',
#  'par_lemma_nicotine',
#  'par_lemma_normal',
#  'par_lemma_note',
#  'par_lemma_novel',
#  'par_lemma_number',
#  'par_lemma_nutrition',
#  'par_lemma_nutritional',
#  'par_lemma_obese',
#  'par_lemma_observe',
#  'par_lemma_obtain',
#  'par_lemma_occur',
#  'par_lemma_occurrence',
#  'par_lemma_ocular',
#  'par_lemma_odd',
#  'par_lemma_old',
#  'par_lemma_older',
#  'par_lemma_onset',
#  'par_lemma_open',
#  'par_lemma_operation',
#  'par_lemma_operative',
#  'par_lemma_opioid',
#  'par_lemma_optimal',
#  'par_lemma_oral',
#  'par_lemma_orally',
#  'par_lemma_order',
#  'par_lemma_outcome',
#  'par_lemma_outpatient',
#  'par_lemma_output',
#  'par_lemma_ovarian',
#  'par_lemma_oxide',
#  'par_lemma_oxygen',
#  'par_lemma_oxytocin',
#  'par_lemma_paclitaxel',
#  'par_lemma_pain',
#  'par_lemma_parallel',
#  'par_lemma_parameter',
#  'par_lemma_partial',
#  'par_lemma_participant',
#  'par_lemma_participate',
#  'par_lemma_participation',
#  'par_lemma_particularly',
#  'par_lemma_patient',
#  'par_lemma_pattern',
#  'par_lemma_peak',
#  'par_lemma_pediatric',
#  'par_lemma_people',
#  'par_lemma_percent',
#  'par_lemma_percentage',
#  'par_lemma_perform',
#  'par_lemma_performance',
#  'par_lemma_period',
#  'par_lemma_peripheral',
#  'par_lemma_person',
#  'par_lemma_pharmacokinetic',
#  'par_lemma_pharmacokinetics',
#  'par_lemma_physical',
#  'par_lemma_pilot',
#  'par_lemma_placebo',
#  'par_lemma_plasma',
#  'par_lemma_platelet',
#  'par_lemma_play',
#  'par_lemma_plus',
#  'par_lemma_point',
#  'par_lemma_poor',
#  'par_lemma_position',
#  'par_lemma_positive',
#  'par_lemma_possible',
#  'par_lemma_postmenopausal',
#  'par_lemma_postoperative',
#  'par_lemma_potential',
#  'par_lemma_power',
#  'par_lemma_pre',
#  'par_lemma_predict',
#  'par_lemma_predictive',
#  'par_lemma_prednisone',
#  'par_lemma_pregnancy',
#  ...]

# %% [markdown]
# < can clear mem >

# %%
xg_train.handle
# Out:
# c_void_p(1792626301920)

# %%
dir_name = Path(f'data\\xgb_test\\{selected_label}')
dir_name.mkdir(exist_ok=True,parents=True)

print('data shape:', xg_train.num_row(), xg_train.num_col())

params = {
    'verbosity': 3,
#     'eta': ?, 
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'tree_method': 'gpu_hist',
    'evals': xg_train,
    'num_rounds': 250,
    'max_depth': 6,  # default 6
    'num_parallel_tree': 1, # default 1
    'scale_pos_weight': 7.0 # set in loop
}

params['nthread'] = 2 # sys.argv with flag
# Out:
# data shape: 23452 2442

# %%
clf = xgb.XGBClassifier(**params)

clf = xgb.train(params, xg_train)
print(f"Classifier loaded. Initalizing training...\n")
# clf.fit(params, xgtrain), # xgtrain
#         eval_set=[xgtrain, xgtest], #xgtrain, xgtest
#         eval_metric='logloss',
#         verbose=True)

#             clf.fit(X_train, y_train[label],
#                     eval_set=[(X_train, y_train[label]), (X_test, y_test[label])], #insert kcv here
#                     eval_metric='logloss',
#                     verbose=True)
# Out:
# [05:27:03] DEBUG: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/tree/updater_gpu_hist.cu:1167: [GPU Hist]: Configure
# [05:27:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\learner.cc:328:
# Parameters: { evals, num_rounds } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-28d65fb3fdb6> in <module>
#       1 clf = xgb.XGBClassifier(**params)
#       2
# ----> 3 clf = xgb.train(params, xg_train, evals=[(xg_train, xg_train.get_label())])
#       4 print(f"Classifier loaded. Initalizing training...\n")
#       5 # clf.fit(params, xgtrain), # xgtrain
#
# ~\Anaconda3\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     207                            evals=evals,
#     208                            obj=obj, feval=feval,
# --> 209                            xgb_model=xgb_model, callbacks=callbacks)
#     210
#     211
#
# ~\Anaconda3\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      82         # check evaluation result.
#      83         if evals:
# ---> 84             bst_eval_set = bst.eval_set(evals, i, feval)
#      85             if isinstance(bst_eval_set, STRING_TYPES):
#      86                 msg = bst_eval_set
#
# ~\Anaconda3\lib\site-packages\xgboost\core.py in eval_set(self, evals, iteration, feval)
#    1303             if not isinstance(d[1], STRING_TYPES):
#    1304                 raise TypeError('expected string, got {}'.format(
# -> 1305                     type(d[1]).__name__))
#    1306             self._validate_features(d[0])
#    1307
#
# TypeError: expected string, got ndarray

# %%
hotcode(features)

# %%
labels

# %%
xgtrain
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-c47989071b65> in <module>
# ----> 1 xgtrain
#
# NameError: name 'xgtrain' is not defined

# %%
try:
    features = hotcode(features)
except ValueError:
    print('No categorical values found in data')
    
features

# %% [markdown]
# Saving DMatrix into a XGBoost binary file will make loading faster:

# %%
data = pd.DataFrame(np.arange(12).reshape((4,3)), columns=['a', 'b', 'c'])
label = pd.DataFrame(np.random.randint(2, size=4))
dtrain = xgboost.DMatrix(data, label=label)
dtrain

# %%
drop.axis(1)
labels

# %%
labels["interventions"]

dtrain = xgboost.DMatrix('train.svm.txt')
dtrain.save_binary('train.buffer')

# %% [markdown]
# # bin

# %%
# from pathlib import Path
# import xgboost as xgb
   
# xgtrain = xgb.DMatrix("train.buffer#dtrain.cache")
# xgtrain.feature_names = dmatrix.feature_names
# xgtrain.feature_types = dmatrix.feature_types
# xgtrain.handle = dmatrix.handle
# xgtrain._feature_names = dmatrix._feature_names
# xgtrain._feature_types = dmatrix._feature_types

# del dmatrix
# Out:
# [05:07:42] 23452x2442 matrix with 57269784 entries loaded from train.buffer#dtrain.cache

# %%
# features = pd.read_parquet('train3_100.parquet') # X
# labels = pd.read_parquet('data/labels_sent.parquet') # y

# # print(features.index)

# df = labels.loc[(features.index.unique('doc'), slice(None), slice(None))]

# # df = labels.loc[features.index]

# df.to_parquet('data/labels_sent_100.parquet')
# # df.to_parquet()
# print(df)

# %%
# ## Validation Split(s) if desired

#     k_folds = 5

#     train_idx, val_idx = train_test_split(df.index.unique('doc'),
#                                           train_size=1 - (1 / k_folds))  # default 80:20

#     print(f'Performing a {len(train_idx)}:{len(val_idx)} train/test split.')

#     train_set = df.loc[(train_idx, slice(None)), :]
#     val_set = df.loc[(val_idx, slice(None)), :]

# #     X_train_df, y_train_df = train_set[features['all']], train_set[PIO]
# #     X_test_df, y_test_df = val_set[features['all']], val_set[PIO]

#     start_time = time.time()
#     try:
#         X_train, X_test = hotcode(X_train_df), hotcode(X_test_df)
#     except ValueError:
#         print('No categorical values found in data')

#     print(f'\nOne-hot coding took {time.time() - start_time:.2f}s.\n')

# %%
# for feature_set, feats in features.items():
#         if feature_set != 'all': print('done'); break

#         y_pred = words.loc[y_test.index].to_frame().join(y_test)  # index=y_test.index)#, columns=labels)

#         start_time = time.time()

#         for label in labels:

#             print(f"Training a GBC model to predict label '{label}'.")
#             print('Starting XGBoost.')

#             params['scale_pos_weight'] = (len(y_train) - sum(y_train[label])) / sum(y_train[label])
#             clf = xgboost.XGBClassifier(**params)

#             clf.fit(X_train, y_train[label],
#                     eval_set=[(X_train, y_train[label]), (X_test, y_test[label])], #insert kcv here
#                     eval_metric='logloss',
#                     verbose=True)

#             evals_result = clf.evals_result()

#             clf = clf.fit(X_train, y_train[label])
#             score = clf.score(X_test, y_test[label])

#             targets = np.delete(clf.classes_, 0)

#             y_pred[f'{label}_pred'] = clf.predict(X_test)

#             report = pd.DataFrame(
#                 classification_report(y_test[label].values.flatten(), y_pred[f'{label}_pred'].values.flatten(),
#                                       labels=targets, digits=3, output_dict=True)
#             )

#             print(report)
#             time.sleep(3)

#             print(f"Saving data for run with features '{feature_set}' and target '{label}' in '{dir_name}'")

#             model_name = f'_{label}_{feature_set}'

#             save_model = True
#             if save_model:
#                 Path(f'models/{dir_name}').mkdir(exist_ok=True, parents=True)
#                 clf.save_model(f'models/{dir_name}/{model_name}.xgbm')

#             exp_folder = EXPERIMENTS / dir_name / model_name
#             exp_folder.mkdir(exist_ok=True, parents=True)

#             report.to_csv(exp_folder / 'class_report.csv')
#             y_pred.to_csv(exp_folder / 'predictions.csv')
#             pd.to_pickle(evals_result, exp_folder / 'evals_result.pickle')

#             with open(exp_folder / '.params', 'w') as f:
#                 f.write('\n'.join([f'{k}, {v}' for k, v in params.items()]))

#             pd.DataFrame(clf.predict_proba(X_test), index=y_pred.index, columns=[f'not {label}', label]) \
#               .to_csv(exp_folder / 'predict_proba.csv')

#             print(f'\n{time.time() - start_time:.2f}')

#     print('Done')


# if __name__ == '__main__':
#     main()
